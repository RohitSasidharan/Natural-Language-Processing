# %% [markdown]
# <a href="https://colab.research.google.com/github/RohitSasidharan/Natural-Language-Processing/blob/main/TextClassifaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import numpy as np
import re
import nltk
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split
import h2o
from h2o.automl import H2OAutoML
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix

h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         20 mins 05 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.1.3
# H2O_cluster_version_age:    1 month and 4 days
# H2O_cluster_name:           H2O_from_python_unknownUser_fow3dl
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.174 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.10 final
# --------------------------  ------------------------------------------------------------------

# %%
pip install h2o
# Out:
# Requirement already satisfied: h2o in /usr/local/lib/python3.7/dist-packages (3.32.1.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from h2o) (0.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from h2o) (0.8.9)
# Requirement already satisfied: colorama>=0.3.8 in /usr/local/lib/python3.7/dist-packages (from h2o) (0.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from h2o) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2.10)

# %%
df=pd.read_csv('https://github.com/srivatsan88/YouTubeLI/blob/master/dataset/consumer_compliants.zip?raw=true', compression='zip', sep=',', quotechar='"')

df['Product'].value_counts()
# Out:
# Debt collection                21772
# Credit card or prepaid card    13193
# Mortgage                       9799
# Checking or savings account    7003
# Student loan                   2950
# Vehicle loan or lease          2736
# Name: Product, dtype: int64

# %%
complaints_df=df[['Consumer complaint narrative','Product','Company']].rename(columns={'Consumer complaint narrative':'complaints'})
pd.set_option('display.max_colwidth', -1)
complaints_df
target={'Debt collection':0, 'Credit card or prepaid card':1, 'Mortgage':2, 'Checking or savings account':3, 'Student loan':4, 'Vehicle loan or lease':5}
complaints_df['target']=complaints_df['Product'].map(target)

# %%
X_train, X_test = train_test_split(complaints_df, test_size=0.2, random_state=111)
stemmer = nltk.stem.SnowballStemmer('english')
nltk.download('stopwords')
stop_words = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def tokenize(text):
   tokens = [word for word in nltk.word_tokenize(text) if (len(word) > 3 and len(word.strip('Xx/')) > 2 and len(re.sub('\d+', '', word.strip('Xx/'))) > 3) ] 
   tokens = map(str.lower, tokens)
   stems = [stemmer.stem(item) for item in tokens if (item not in stop_words)]
   return stems

# %%
vectorizer_tf = TfidfVectorizer(tokenizer=tokenize, stop_words=None, max_df=0.75, max_features=1000, lowercase=False, ngram_range=(1,2))
train_vectors = vectorizer_tf.fit_transform(X_train.complaints)
train_vectors.A
vectorizer_tf.get_feature_names()
test_vectors = vectorizer_tf.transform(X_test.complaints)
X_train.shape
# Out:
# (45962, 4)

# %%
train_df=pd.DataFrame(train_vectors.toarray(), columns=vectorizer_tf.get_feature_names())
train_df=pd.concat([train_df,X_train['target'].reset_index(drop=True)], axis=1)
train_df
# Out:
#        abil       abl  absolut  abus  ...  wrong  wrote      year  target
# 0      0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  3
# 1      0.0   0.059822  0.0      0.0   ...  0.0    0.0    0.047990  0
# 2      0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  0
# 3      0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  1
# 4      0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  3
# ...    ...        ...  ...      ...   ...  ...    ...         ... ..
# 45957  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  1
# 45958  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  2
# 45959  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.095827  1
# 45960  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  1
# 45961  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  2
#
# [45962 rows x 1001 columns]

# %%
test_df=pd.DataFrame(test_vectors.toarray(), columns=vectorizer_tf.get_feature_names())
test_df=pd.concat([test_df,X_test['target'].reset_index(drop=True)], axis=1)
test_df
# Out:
#        abil       abl  absolut  abus  ...  wrong  wrote      year  target
# 0      0.0   0.086928  0.0      0.0   ...  0.0    0.0    0.000000  3
# 1      0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  2
# 2      0.0   0.146798  0.0      0.0   ...  0.0    0.0    0.000000  1
# 3      0.0   0.088469  0.0      0.0   ...  0.0    0.0    0.070970  4
# 4      0.0   0.079911  0.0      0.0   ...  0.0    0.0    0.128210  1
# ...    ...        ...  ...      ...   ...  ...    ...         ... ..
# 11486  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.032876  1
# 11487  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  4
# 11488  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  2
# 11489  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.077801  0
# 11490  0.0   0.000000  0.0      0.0   ...  0.0    0.0    0.000000  0
#
# [11491 rows x 1001 columns]

# %%
h2o_train_df = h2o.H2OFrame(train_df)
h2o_test_df = h2o.H2OFrame(test_df)
h2o_train_df.types

h2o_train_df['target'] = h2o_train_df['target'].asfactor()
h2o_test_df['target'] = h2o_test_df['target'].asfactor()
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
aml = H2OAutoML(max_models = 10, seed = 10, exclude_algos = ["StackedEnsemble"], verbosity="info", nfolds=0, balance_classes=True, max_after_balance_size=0.3)

# %%
x=vectorizer_tf.get_feature_names()
y='target'

# %%
aml.train(x = x, y = y, training_frame = h2o_train_df, validation_frame=h2o_test_df)
# Out:
# AutoML progress: |
# 10:56:15.899: Project: AutoML_20210624_105615894
# 10:56:15.909: Cross-validation disabled by user: no fold column nor nfolds > 1.
# 10:56:15.940: Setting stopping tolerance adaptively based on the training frame: 0.00466445106034528
# 10:56:15.941: Build control seed: 10
# 10:56:15.941: Since cross-validation is disabled, and no leaderboard frame was provided, automatically split the training data into training and leaderboard frames in the ratio 90/10
# 10:56:21.584: training frame: Frame key: automl_training_py_1_sid_ae3e    cols: 1001    rows: 41253  chunks: 53    size: 34326323  checksum: -3708572512705517030
# 10:56:21.588: validation frame: Frame key: py_2_sid_ae3e    cols: 1001    rows: 11491  chunks: 14    size: 9663839  checksum: 6186608125092982850
# 10:56:21.884: leaderboard frame: Frame key: automl_leaderboard_py_1_sid_ae3e    cols: 1001    rows: 4709  chunks: 53    size: 7556253  checksum: 384529285802033387
# 10:56:21.884: blending frame: NULL
# 10:56:21.884: response column: target
# 10:56:21.884: fold column: null
# 10:56:21.884: weights column: null
# 10:56:21.936: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 10:56:21.952: Disabling Algo: StackedEnsemble as requested by the user.
# 10:56:21.957: AutoML job created: 2021.06.24 10:56:15.894
# 10:56:21.957: AutoML build started: 2021.06.24 10:56:21.957
# 10:56:21.974: AutoML: starting XGBoost_1_AutoML_20210624_105615 model training
#
# ██
# 11:03:12.729: New leader: XGBoost_1_AutoML_20210624_105615, mean_per_class_error: 0.14815851674932912
# 11:03:12.730: AutoML: starting XGBoost_2_AutoML_20210624_105615 model training
#
# █████████████████████████████████████
# 11:09:06.550: AutoML: starting XGBoost_3_AutoML_20210624_105615 model training
#
# ██████████
# 11:14:14.30: New leader: XGBoost_3_AutoML_20210624_105615, mean_per_class_error: 0.14703102227636622
# 11:14:14.32: AutoML: starting GLM_1_AutoML_20210624_105615 model training
#
# █████
# 11:23:31.198: AutoML: starting DRF_1_AutoML_20210624_105615 model training
#
# █
# 11:28:19.5: AutoML: starting GBM_1_AutoML_20210624_105615 model training
# 11:40:51.254: AutoML: starting GBM_2_AutoML_20210624_105615 model training
#
#
# 11:56:11.712: AutoML: starting GBM_3_AutoML_20210624_105615 model training
#
# █
# 12:12:49.130: AutoML: starting GBM_4_AutoML_20210624_105615 model training
#
#
# 12:36:09.704: AutoML: starting GBM_5_AutoML_20210624_105615 model training
#
# | 100%
#
# 12:56:36.958: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 12:56:36.961: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 12:56:36.962: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 12:56:36.962: Actual modeling steps: [{XGBoost : [def_1 (10), def_2 (10), def_3 (10)]}, {GLM : [def_1 (10)]}, {DRF : [def_1 (10)]}, {GBM : [def_1 (10), def_2 (10), def_3 (10), def_4 (10), def_5 (10)]}]
# 12:56:36.962: AutoML build stopped: 2021.06.24 12:56:36.962
# 12:56:36.962: AutoML build done: built 10 models
# 12:56:36.963: AutoML duration:  2:00:15.005

# %%
aml.leaderboard
# Out:
# <table>
# <thead>
# <tr><th>model_id                        </th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">      mse</th><th style="text-align: right;">  auc</th><th style="text-align: right;">  aucpr</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoost_3_AutoML_20210624_105615</td><td style="text-align: right;">              0.147031</td><td style="text-align: right;"> 0.326389</td><td style="text-align: right;">0.309   </td><td style="text-align: right;">0.095481 </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>XGBoost_1_AutoML_20210624_105615</td><td style="text-align: right;">              0.148159</td><td style="text-align: right;"> 0.32431 </td><td style="text-align: right;">0.306762</td><td style="text-align: right;">0.094103 </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_4_AutoML_20210624_105615    </td><td style="text-align: right;">              0.151171</td><td style="text-align: right;"> 0.394758</td><td style="text-align: right;">0.332497</td><td style="text-align: right;">0.110554 </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>XGBoost_2_AutoML_20210624_105615</td><td style="text-align: right;">              0.151607</td><td style="text-align: right;"> 0.3315  </td><td style="text-align: right;">0.307789</td><td style="text-align: right;">0.0947342</td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_2_AutoML_20210624_105615    </td><td style="text-align: right;">              0.151666</td><td style="text-align: right;"> 0.380813</td><td style="text-align: right;">0.333907</td><td style="text-align: right;">0.111494 </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_3_AutoML_20210624_105615    </td><td style="text-align: right;">              0.152864</td><td style="text-align: right;"> 0.376541</td><td style="text-align: right;">0.332445</td><td style="text-align: right;">0.11052  </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_5_AutoML_20210624_105615    </td><td style="text-align: right;">              0.152887</td><td style="text-align: right;"> 0.369896</td><td style="text-align: right;">0.325249</td><td style="text-align: right;">0.105787 </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_1_AutoML_20210624_105615    </td><td style="text-align: right;">              0.162558</td><td style="text-align: right;"> 0.401623</td><td style="text-align: right;">0.345223</td><td style="text-align: right;">0.119179 </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GLM_1_AutoML_20210624_105615    </td><td style="text-align: right;">              0.170193</td><td style="text-align: right;"> 0.379036</td><td style="text-align: right;">0.335487</td><td style="text-align: right;">0.112552 </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>DRF_1_AutoML_20210624_105615    </td><td style="text-align: right;">              0.277178</td><td style="text-align: right;"> 0.592434</td><td style="text-align: right;">0.443854</td><td style="text-align: right;">0.197007 </td><td style="text-align: right;">  nan</td><td style="text-align: right;">    nan</td></tr>
# </tbody>
# </table>

# %%
pred=aml.leader.predict(h2o_test_df)
aml.leader.model_performance(h2o_test_df)
# Out:
# xgboost prediction progress: |████████████████████████████████████████████| 100%
#
# ModelMetricsMultinomial: xgboost
# ** Reported on test data. **
#
# MSE: 0.09874642455571268
# RMSE: 0.31423943825642364
# LogLoss: 0.332124508002221
# Mean Per-Class Error: 0.16007678918359133
# AUC: NaN
# AUCPR: NaN
# Multinomial auc values: Table is not computed because it is disabled (model parameter 'auc_type' is set to AUTO or NONE) or due to domain size (maximum is 50 domains).
# Multinomial auc_pr values: Table is not computed because it is disabled (model parameter 'auc_type' is set to AUTO or NONE) or due to domain size (maximum is 50 domains).
#
# Confusion Matrix: Row labels: Actual class; Column labels: Predicted class
#         0       1       2       3      4      5     Error            Rate
# 0  4003.0   127.0    54.0    28.0   36.0   47.0  0.067986     292 / 4,295
# 1   189.0  2281.0    18.0    83.0    0.0   12.0  0.116918     302 / 2,583
# 2    79.0    29.0  1858.0    18.0    4.0   27.0  0.077916     157 / 2,015
# 3    46.0   144.0    17.0  1245.0    2.0    7.0  0.147844     216 / 1,461
# 4    61.0    22.0    21.0     1.0  483.0   23.0  0.209493       128 / 611
# 5    90.0    39.0    36.0     9.0    5.0  347.0  0.340304       179 / 526
# 6  4468.0  2642.0  2004.0  1384.0  530.0  463.0  0.110869  1,274 / 11,491
# Top-6 Hit Ratios:
#    k  hit_ratio
# 0  1   0.889131
# 1  2   0.965364
# 2  3   0.985554
# 3  4   0.993647
# 4  5   0.998260
# 5  6   1.000000

# %%
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
out = h2o.get_model([mid for mid in model_ids if "XGBoost" in mid][0])
out
out.convert_H2OXGBoostParams_2_XGBoostParams()
# Out:
# ({'alpha': 0.0,
#   'booster': 'gbtree',
#   'colsample_bylevel': 0.8,
#   'colsample_bytree': 0.8,
#   'eta': 0.3,
#   'gamma': 0.0,
#   'grow_policy': 'depthwise',
#   'lambda': 1.0,
#   'max_delta_step': 0.0,
#   'max_depth': 5,
#   'min_child_weight': 3.0,
#   'nround': 10000,
#   'nthread': 2,
#   'num_class': 6,
#   'objective': 'multi:softprob',
#   'seed': 12,
#   'silent': True,
#   'subsample': 0.8,
#   'tree_method': 'exact'},
#  10000)

# %%
xgb_clf = xgb.XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=6, objective='multi:softprob', random_state=10)
xgb_clf.fit(train_vectors, X_train['target'])
predictions = xgb_clf.predict(test_vectors)
cm = confusion_matrix(X_test['target'], predictions)
print(cm)
print('classification_report :\n',classification_report(X_test['target'], predictions))
# Out:
# classification_report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      4295
#            1       0.85      0.85      0.85      2583
#            2       0.92      0.90      0.91      2015
#            3       0.88      0.83      0.85      1461
#            4       0.89      0.75      0.82       611
#            5       0.74      0.61      0.67       526
#
#     accuracy                           0.87     11491
#    macro avg       0.85      0.81      0.83     11491
# weighted avg       0.86      0.87      0.86     11491

# %%
from sklearn.utils import class_weight
class_weights = list(class_weight.compute_class_weight('balanced',
                                             np.unique(X_train['target']),
                                             X_train['target']))
class_weights
weights = np.ones(X_train.shape[0], dtype = 'float')
weights
